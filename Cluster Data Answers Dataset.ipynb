# %%
# Import library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize
sns.set()

# %% [markdown]
# Preprocessing

# %%
# Read data

cluster_data = pd.read_csv(r'cluster.csv')

cluster_data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# Describe data

cluster_data.describe(include = 'all')

# Data contains null
# CUST_ID is categoric variable, There are many unique ones
# CUST_ID is unnecessary column
# Out:
#        CUST_ID       BALANCE  BALANCE_FREQUENCY     PURCHASES  \
# count     8950   8950.000000        8950.000000   8950.000000
# unique    8950           NaN                NaN           NaN
# top     C10001           NaN                NaN           NaN
# freq         1           NaN                NaN           NaN
# mean       NaN   1564.474828           0.877271   1003.204834
# std        NaN   2081.531879           0.236904   2136.634782
# min        NaN      0.000000           0.000000      0.000000
# 25%        NaN    128.281915           0.888889     39.635000
# 50%        NaN    873.385231           1.000000    361.280000
# 75%        NaN   2054.140036           1.000000   1110.130000
# max        NaN  19043.138560           1.000000  49039.570000
#
#         ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# count        8950.000000             8950.000000   8950.000000
# unique               NaN                     NaN           NaN
# ...

# %%
# Duplicate check

cluster_data.duplicated().sum()

# If there is a duplicate, delete it

cluster_data.drop_duplicates(inplace = True)

# %%
# Drop unnecessary column
cluster_data.drop('CUST_ID', axis = 1, inplace = True)

cluster_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_data.dtypes
# Out:
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
# Check Null

cluster_data.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# If there is a null, fill

for rec in cluster_data.columns:
    if cluster_data[rec].dtypes != object:
        cluster_data[rec].fillna(value = cluster_data[rec].mean(), inplace = True)
    else:
        cluster_data[rec].fillna(value = cluster_data[rec].mode()[0], inplace = True)
        
cluster_data.isnull().sum()


# null dəyərlər datanın 10-15 faizindən aşağı olduğuna görə fillna ed
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# outlier treatment

for rec in cluster_data.columns:
    if cluster_data[rec].dtypes != object:
        sns.boxplot(x = cluster_data[rec], data = cluster_data)
        plt.show()

# %%
# Handle outliers with IQR methods

for rec in cluster_data.columns:
    if cluster_data[rec].dtype != object:
        q1 = cluster_data[rec].quantile(0.25)
        q3 = cluster_data[rec].quantile(0.75)
        IQR = q3 - q1
        lower = q1 - 1.5 * IQR
        upper = q3 + 1.5 * IQR
        cluster_data[rec] = np.where(cluster_data[rec] > upper,
                                     upper,
                                     np.where(cluster_data[rec] < lower,
                                     lower,
                                     cluster_data[rec]))

# %%
for rec in cluster_data.columns:
    if cluster_data[rec].dtypes != object:
        sns.boxplot(x = cluster_data[rec], data = cluster_data)
        plt.show()

# %% [markdown]
# K-means

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

wcss = []
silhouette_scores = []

for i in range(2, 7):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(cluster_data)
    
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
    
    y = kmeans.fit_predict(cluster_data)
    silhouette_avg = silhouette_score(cluster_data, y)
    silhouette_scores.append(silhouette_avg)
    
    print("Cluster: ", i)
    print("WCSS: ", wcss_iter)
    print("Silhouette Score: ", silhouette_avg)
# Out:
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Cluster:  2
# WCSS:  77927409772.32272
# Silhouette Score:  0.48281181495467157
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
number_clusters = range(2,7)

plt.plot(number_clusters,wcss)

plt.title('The Elbow Method')

plt.xlabel('Number of clusters')

plt.ylabel('Within-cluster Sum of Squares')


# qırılma 3 nöqtədədir (3, 4, 5)
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %%
kmeans = KMeans(5) # k =>>>> 5

# %%
kmeans.fit(cluster_data)
# Out:
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %%
y = kmeans.fit_predict(cluster_data)
# Out:
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
data_with_kmeans = cluster_data.copy()

data_with_kmeans
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 1     3202.467416           0.909091       0.00            0.0000
# 2     2495.148862           1.000000     773.17          773.1700
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12            0.0000
# 8946    19.183215           1.000000     300.00            0.0000
# 8947    23.398673           0.833333     144.40            0.0000
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
data_with_kmeans['Cluster'] = y

data_with_kmeans
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 1     3202.467416           0.909091       0.00            0.0000
# 2     2495.148862           1.000000     773.17          773.1700
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12            0.0000
# 8946    19.183215           1.000000     300.00            0.0000
# 8947    23.398673           0.833333     144.40            0.0000
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# Calc Silhouette Score

silhouette_avg = silhouette_score(data_with_kmeans, y)

print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.2872411197980938

# %% [markdown]
# AgglomerativeClustering

# %%
# Copy data for AgglomerativeClustering

data_with_agg = cluster_data.copy()

data_with_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 1     3202.467416           0.909091       0.00            0.0000
# 2     2495.148862           1.000000     773.17          773.1700
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12            0.0000
# 8946    19.183215           1.000000     300.00            0.0000
# 8947    23.398673           0.833333     144.40            0.0000
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# Data normalization

data_scaled = normalize(data_with_agg)

data_scaled = pd.DataFrame(data_scaled, columns = data_with_agg.columns)

data_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.039353           0.000787   0.091790          0.000000
# 1  0.347368           0.000099   0.000000          0.000000
# 2  0.310798           0.000125   0.096307          0.096307
# 3  0.208094           0.000090   0.187159          0.180231
# 4  0.504284           0.000617   0.009867          0.009867
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                 0.09179      0.000000             0.000160
# 1                 0.00000      0.302037             0.000000
# 2                 0.00000      0.000000             0.000125
# 3                 0.00000      0.025694             0.000010
# 4                 0.00000      0.000000             0.000051
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                           0.00008
# 1                    0.000000                           0.00000
# ...

# %%
plt.figure(figsize = (10, 7))  

plt.title("Dendrograms")  

dend = shc.dendrogram(shc.linkage(data_scaled, method = 'ward'))

# %%
plt.figure(figsize=(10, 7)) 
plt.title("Dendrograms") 
dend = shc.dendrogram(shc.linkage(data_scaled, method = 'ward'))
plt.axhline(y = 20, color = 'r', linestyle = '--')

# %%
# 3 nöqtədə kəsir

cluster = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')  
y = cluster.fit_predict(data_scaled)
y
# Out:
# /Users/imanovaax/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([1, 2, 1, ..., 1, 1, 0])

# %%
data_with_agg['Cluster'] = y

data_with_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 1     3202.467416           0.909091       0.00            0.0000
# 2     2495.148862           1.000000     773.17          773.1700
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12            0.0000
# 8946    19.183215           1.000000     300.00            0.0000
# 8947    23.398673           0.833333     144.40            0.0000
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# Calc Silhouette Score

silhouette_avg = silhouette_score(data_scaled, y)

print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.2610959865430722
